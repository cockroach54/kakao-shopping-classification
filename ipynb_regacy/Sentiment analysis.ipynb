# %% [markdown]
# # Sentiment analysis
# > - naver movier review

# %%
import csv
from pprint import pprint

# tsv load
with open('corpus/naver_movie_corpus/ratings_train.txt', 'r', encoding='utf-8') as f:
    rdr = csv.reader(f, delimiter='\t')
    naver_train = list(rdr)
    naver_train = naver_train[1:]
    
with open('corpus/naver_movie_corpus/ratings_test.txt', 'r', encoding='utf-8') as f:
    rdr = csv.reader(f, delimiter='\t')
    naver_test = list(rdr)
    naver_test = naver_test[1:]

pprint(naver_train[35:42])
# Out:
# [['4726746', '패션에 대한 열정! 안나 윈투어!', '1'],
#  ['7203432', '키이라 나이틀리가 연기하고자 했던건 대체 정신장애일까 틱장애일까', '0'],
#  ['112724', '허허...원작가 정신나간 유령이라... 재미있겠네요!', '1'],
#  ['1105872', '포스터는 있어보이는데 관객은 114명이네', '0'],
#  ['4805788', '이 영화가 왜 이렇게 저평가 받는지 모르겠다', '1'],
#  ['9336496', '단순하면서 은은한 매력의 영화', '1'],
#  ['9994900',
#   "'다 알바생인가 내용도 없고 무서운거도 없고 웃긴거도 하나도 없음 완전 별싱거운 영화.ㅇ.ㅇ내ㅇ시간 넘 아까움 .. . 완전 낚임",
#   '0']]

# %%
# pos tagging, tokenizing
from tqdm import tqdm_notebook
from konlpy.tag import Twitter
tagger = Twitter()

# *****pos tagging에 시간 좀 걸립니다******
def tokenize(doc):
    return ['/'.join(t) for t in tagger.pos(doc, norm=True, stem=True)]

sentences = []
naver_tot = naver_train+naver_test
naver_tot = naver_tot[:5000] # 노트북에서 돌릴때 데이터 줄이기
for sentence in tqdm_notebook(naver_tot):
    sentences.append(tokenize(sentence[1]))
# Out:
# A Jupyter Widget

# %%
print('문장 총 개수: ', len(sentences))
for i in range(5):
    print(sentences[i])
# Out:
# 문장 총 개수:  5000
# ['아/Exclamation', '더빙/Noun', '../Punctuation', '진짜/Noun', '짜증/Noun', '나다/Verb', '목소리/Noun']
# ['흠/Noun', '.../Punctuation', '포스터/Noun', '보고/Noun', '초딩/Noun', '영화/Noun', '줄/Noun', '..../Punctuation', '오버/Noun', '연기/Noun', '조차/Josa', '가볍다/Adjective', '않다/Verb']
# ['너무/Noun', '재/Noun', '밓었/Noun', '다/Josa', '그래서/Adverb', '보다/Verb', '추천/Noun', '하다/Verb']
# ['교도소/Noun', '이야기/Noun', '구먼/Noun', '../Punctuation', '솔직하다/Adjective', '재미/Noun', '는/Josa', '없다/Adjective', '../Punctuation', '평점/Noun', '조정/Noun']
# ['사이몬페그/Noun', '의/Josa', '익살/Noun', '스런/Josa', '연기/Noun', '가/Josa', '돋보이다/Verb', '영화/Noun', '!/Punctuation', '스파이더맨/Noun', '에서/Josa', '늙다/Verb', '보이다/Verb', '하다/Verb', '크다/Verb', '스틴/Noun', '던스트/Noun', '가/Josa', '너무나/Noun', '도/Josa', '이쁘다/Adjective', '보이다/Verb']

# %%
from gensim import models
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
# %%time
size=100
model = models.Word2Vec(size=size, window=7, min_count=5, workers=8,alpha=0.025, min_alpha=0.025)

model.build_vocab(sentences) # 오로지 한번만 스트럭팅 가능

# learning_rate를 낮춰가며 여러번 트레이닝
for epoch in range(15):
    if epoch%1 ==0:
        print('epoch:',epoch, 'train completed')
    model.train(sentences, total_examples=model.corpus_count, epochs=model.iter)
    model.alpha -= 0.002  # decrease the learning rate
    model.min_alpha = model.alpha  # fix the learning rate, no decay
# Out:
# epoch: 0 train completed
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: DeprecationWarning: Call to deprecated `iter` (Attribute will be removed in 4.0.0, use self.epochs instead).
#   # Remove the CWD from sys.path while we load stuff.
# epoch: 1 train completed
# epoch: 2 train completed
# epoch: 3 train completed
# epoch: 4 train completed
# epoch: 5 train completed
# epoch: 6 train completed
# epoch: 7 train completed
# epoch: 8 train completed
# epoch: 9 train completed
# epoch: 10 train completed
# epoch: 11 train completed
# epoch: 12 train completed
# epoch: 13 train completed
# epoch: 14 train completed
# Wall time: 2.4 s

# %%
model.wv.vocab
# Out:
# {'아/Exclamation': <gensim.models.keyedvectors.Vocab at 0x24e48a63e10>,
#  '더빙/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a63e80>,
#  '../Punctuation': <gensim.models.keyedvectors.Vocab at 0x24e48a63e48>,
#  '진짜/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a63cc0>,
#  '짜증/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a84be0>,
#  '나다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a84c18>,
#  '목소리/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a84c50>,
#  '흠/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a84c88>,
#  '.../Punctuation': <gensim.models.keyedvectors.Vocab at 0x24e48a84cc0>,
#  '포스터/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a84cf8>,
#  '보고/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a84d30>,
#  '초딩/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a84d68>,
#  '영화/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a84da0>,
#  '줄/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a84dd8>,
#  '..../Punctuation': <gensim.models.keyedvectors.Vocab at 0x24e48a84e10>,
#  '오버/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a84e48>,
#  '연기/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a84e80>,
#  '조차/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a84eb8>,
#  '가볍다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a84ef0>,
#  '않다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a84f28>,
#  '너무/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a84f60>,
#  '재/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a84f98>,
#  '다/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a84fd0>,
#  '그래서/Adverb': <gensim.models.keyedvectors.Vocab at 0x24e48a7b048>,
#  '보다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a7b080>,
#  '추천/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a7b0b8>,
#  '하다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a7b0f0>,
#  '이야기/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a7b128>,
#  '솔직하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a7b160>,
#  '재미/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a7b198>,
#  '는/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a7b1d0>,
#  '없다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a7b208>,
#  '평점/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a7b240>,
#  '의/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a7b278>,
#  '스런/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a7b2b0>,
#  '가/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a7b2e8>,
#  '돋보이다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a7b320>,
#  '!/Punctuation': <gensim.models.keyedvectors.Vocab at 0x24e48a7b358>,
#  '스파이더맨/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a7b390>,
#  '에서/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a7b3c8>,
#  '보이다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a7b400>,
#  '크다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a7b438>,
#  '너무나/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a7b470>,
#  '도/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a7b4a8>,
#  '이쁘다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a7b4e0>,
#  '막/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a7b518>,
#  '마/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a7b550>,
#  '떼다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a7b588>,
#  '3/Number': <gensim.models.keyedvectors.Vocab at 0x24e48a7b5c0>,
#  '세/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a7b5f8>,
#  '부터/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a7b630>,
#  '초등학교/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a7b668>,
#  '1/Number': <gensim.models.keyedvectors.Vocab at 0x24e48a7b6a0>,
#  '학년/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a7b6d8>,
#  '8/Number': <gensim.models.keyedvectors.Vocab at 0x24e48a7b710>,
#  '살다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a7b748>,
#  './Punctuation': <gensim.models.keyedvectors.Vocab at 0x24e48a7b780>,
#  'ㅋㅋ/KoreanParticle': <gensim.models.keyedvectors.Vocab at 0x24e48a7b7b8>,
#  '개/Suffix': <gensim.models.keyedvectors.Vocab at 0x24e48a7b7f0>,
#  '아깝다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a7b828>,
#  '움/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a7b860>,
#  '원작/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a7b898>,
#  '긴장감/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a7b8d0>,
#  '을/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a7b908>,
#  '제대로/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a7b940>,
#  '살리다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a7b978>,
#  '별/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a7b9b0>,
#  '반개/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a7b9e8>,
#  '욕/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a7ba20>,
#  '나오다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a7ba58>,
#  '이/Determiner': <gensim.models.keyedvectors.Vocab at 0x24e48a7ba90>,
#  '몇/NounPrefix': <gensim.models.keyedvectors.Vocab at 0x24e48a7bac8>,
#  '년/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a7bb00>,
#  '인지/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a7bb38>,
#  '정말/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a7bb70>,
#  '발/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a7bba8>,
#  '로/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a7bbe0>,
#  '해도/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a7bc18>,
#  '그것/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a7bc50>,
#  '보단/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a7bc88>,
#  '낫다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a7bcc0>,
#  '만/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a7bcf8>,
#  '반복/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a7bd30>,
#  '드라마/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a7bd68>,
#  '가족/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a7bda0>,
#  '못/VerbPrefix': <gensim.models.keyedvectors.Vocab at 0x24e48a7bdd8>,
#  '사람/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a7be10>,
#  '네/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a7be48>,
#  '액션/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a7be80>,
#  '이/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a7beb8>,
#  '있다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a7bef0>,
#  '몇/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a7bf28>,
#  '안/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a7bf60>,
#  '되다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a7bf98>,
#  '왜/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a7bfd0>,
#  '이렇게/Adverb': <gensim.models.keyedvectors.Vocab at 0x24e48a83048>,
#  '낮다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a83080>,
#  '?/Punctuation': <gensim.models.keyedvectors.Vocab at 0x24e48a830b8>,
#  '꽤/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a830f0>,
#  '볼/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a83128>,
#  '한/Determiner': <gensim.models.keyedvectors.Vocab at 0x24e48a83160>,
#  '데/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a83198>,
#  '식/Suffix': <gensim.models.keyedvectors.Vocab at 0x24e48a831d0>,
#  '화려하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a83208>,
#  '길/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a83240>,
#  '들이다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a83278>,
#  '걍/Adverb': <gensim.models.keyedvectors.Vocab at 0x24e48a832b0>,
#  '짱/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a832e8>,
#  '이다/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a83320>,
#  '짱/Suffix': <gensim.models.keyedvectors.Vocab at 0x24e48a83358>,
#  '♥/Foreign': <gensim.models.keyedvectors.Vocab at 0x24e48a83390>,
#  '볼때/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a833c8>,
#  '마다/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a83400>,
#  '눈물/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a83438>,
#  '나서다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a83470>,
#  '죽다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a834a8>,
#  '90/Number': <gensim.models.keyedvectors.Vocab at 0x24e48a834e0>,
#  '년대/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a83518>,
#  '자극/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a83550>,
#  '!!/Punctuation': <gensim.models.keyedvectors.Vocab at 0x24e48a83588>,
#  '감성/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a835c0>,
#  '절제/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a835f8>,
#  '멜로/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a83630>,
#  '~/Punctuation': <gensim.models.keyedvectors.Vocab at 0x24e48a83668>,
#  '서/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a836a0>,
#  '손/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a836d8>,
#  '들/Suffix': <gensim.models.keyedvectors.Vocab at 0x24e48a83710>,
#  '고/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a83748>,
#  '때/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a83780>,
#  '뛰다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a837b8>,
#  '치다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a837f0>,
#  '올/NounPrefix': <gensim.models.keyedvectors.Vocab at 0x24e48a83828>,
#  '뻔/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a83860>,
#  '해/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a83898>,
#  '담/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a838d0>,
#  '하고/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a83908>,
#  '깔끔하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a83940>,
#  '좋다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a83978>,
#  '기사/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a839b0>,
#  '그/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a839e8>,
#  '이다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a83a20>,
#  '것/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a83a58>,
#  '취향/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a83a90>,
#  '은/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a83ac8>,
#  '에/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a83b00>,
#  '극장/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a83b38>,
#  '중/Suffix': <gensim.models.keyedvectors.Vocab at 0x24e48a83b70>,
#  '가장/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a83ba8>,
#  '노잼/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a83be0>,
#  '노/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a83c18>,
#  '감동/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a83c50>,
#  '임/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a83c88>,
#  '스토리/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a83cc0>,
#  '어거지/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a83cf8>,
#  'ㄱ/KoreanParticle': <gensim.models.keyedvectors.Vocab at 0x24e48a83d30>,
#  '긴장/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a83d68>,
#  '재밌다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a83da0>,
#  'ㅠㅠ/KoreanParticle': <gensim.models.keyedvectors.Vocab at 0x24e48a83dd8>,
#  '차다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a83e10>,
#  '웃기다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a83e48>,
#  '이기/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a83e80>,
#  '면/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a83eb8>,
#  '코/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a83ef0>,
#  '라고/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a83f28>,
#  '까다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a83f60>,
#  '이라고/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a83f98>,
#  '그냥/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a83fd0>,
#  '난/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a87048>,
#  '처럼/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a87080>,
#  '표절/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a870b8>,
#  '인/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a870f0>,
#  '이해/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a87128>,
#  '뒤/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a87160>,
#  '갈수록/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a87198>,
#  '없어지다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a871d0>,
#  '캐스팅/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a87208>,
#  '과/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a87240>,
#  '산/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a87278>,
#  '뜻/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a872b0>,
#  '내/Determiner': <gensim.models.keyedvectors.Vocab at 0x24e48a872e8>,
#  '자다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a87320>,
#  '자/Suffix': <gensim.models.keyedvectors.Vocab at 0x24e48a87358>,
#  '를/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a87390>,
#  '위/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a873c8>,
#  ',/Punctuation': <gensim.models.keyedvectors.Vocab at 0x24e48a87400>,
#  '이르다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a87438>,
#  '저/Determiner': <gensim.models.keyedvectors.Vocab at 0x24e48a87470>,
#  '놈/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a874a8>,
#  '착하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a874e0>,
#  '절대/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a87518>,
#  '아니다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a87550>,
#  '걸/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a87588>,
#  '요/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a875c0>,
#  '나름/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a875f8>,
#  '한/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a87630>,
#  '듯/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a87668>,
#  '학생/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a876a0>,
#  '놀다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a876d8>,
#  '웃다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a87710>,
#  '건/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a87748>,
#  '재미없다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a87780>,
#  '지루하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a877b8>,
#  '같다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a877f0>,
#  '인데/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a87828>,
#  '도/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a87860>,
#  '넘다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a87898>,
#  '차이/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a878d0>,
#  '남/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a87908>,
#  ';/Punctuation': <gensim.models.keyedvectors.Vocab at 0x24e48a87940>,
#  '별로/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a87978>,
#  '안/VerbPrefix': <gensim.models.keyedvectors.Vocab at 0x24e48a879b0>,
#  '이라도/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a879e8>,
#  'ㅡㅡ/KoreanParticle': <gensim.models.keyedvectors.Vocab at 0x24e48a87a20>,
#  '평범하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a87a58>,
#  '수작/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a87a90>,
#  '이라/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a87ac8>,
#  '는걸/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a87b00>,
#  '주제/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a87b38>,
#  '중반/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a87b70>,
#  '다/Adverb': <gensim.models.keyedvectors.Vocab at 0x24e48a87ba8>,
#  '야/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a87be0>,
#  '납득/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a87c18>,
#  '수/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a87c50>,
#  '그렇다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a87c88>,
#  '꼭/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a87cc0>,
#  '끄다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a87cf8>,
#  '2/Number': <gensim.models.keyedvectors.Vocab at 0x24e48a87d30>,
#  '버리다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a87d68>,
#  '발연기/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a87da0>,
#  '연출/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a87dd8>,
#  '력/Suffix': <gensim.models.keyedvectors.Vocab at 0x24e48a87e10>,
#  '탁월하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a87e48>,
#  '9/Number': <gensim.models.keyedvectors.Vocab at 0x24e48a87e80>,
#  '점/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a87eb8>,
#  '스/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a87ef0>,
#  '다시/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a87f28>,
#  '한번/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a87f60>,
#  '해주다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a87f98>,
#  '적/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a87fd0>,
#  '꽃/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a89048>,
#  '님/Suffix': <gensim.models.keyedvectors.Vocab at 0x24e48a89080>,
#  '완전/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a890b8>,
#  '쓰레기/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a890f0>,
#  '진부/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a89128>,
#  '말/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a89160>,
#  '도안/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a89198>,
#  '돼다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a891d0>,
#  '시간/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a89208>,
#  '별점/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a89240>,
#  '이리/Adverb': <gensim.models.keyedvectors.Vocab at 0x24e48a89278>,
#  '%/Punctuation': <gensim.models.keyedvectors.Vocab at 0x24e48a892b0>,
#  '라도/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a892e8>,
#  '기대하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a89320>,
#  '내/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a89358>,
#  '이다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a89390>,
#  '아직/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a893c8>,
#  '이/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a89400>,
#  '인생/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a89438>,
#  '최고/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a89470>,
#  '대한/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a894a8>,
#  '열정/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a894e0>,
#  '안나/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a89518>,
#  '대체/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a89550>,
#  '정신/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a89588>,
#  '나가다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a895c0>,
#  '재미있다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a895f8>,
#  '관객/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a89630>,
#  '명/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a89668>,
#  '이네/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a896a0>,
#  '평가/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a896d8>,
#  '받다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a89710>,
#  '모르다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a89748>,
#  '단순하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a89780>,
#  '매력/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a897b8>,
#  "'/Punctuation": <gensim.models.keyedvectors.Vocab at 0x24e48a897f0>,
#  '인가/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a89828>,
#  '내용/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a89860>,
#  '무섭다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a89898>,
#  '하나/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a898d0>,
#  'ㅇ/KoreanParticle': <gensim.models.keyedvectors.Vocab at 0x24e48a89908>,
#  '오다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a89940>,
#  '두다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a89978>,
#  '맘/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a899b0>,
#  '들다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a899e8>,
#  '또/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a89a20>,
#  '방법/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a89a58>,
#  '이라는/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a89a90>,
#  '멋지다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a89ac8>,
#  '배우/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a89b00>,
#  '발견/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a89b38>,
#  '잔잔/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a89b70>,
#  '미소/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a89ba8>,
#  '게/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a89be0>,
#  '음악/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a89c18>,
#  '조금/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a89c50>,
#  '아쉽다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a89c88>,
#  '주다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a89cc0>,
#  '싶다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a89cf8>,
#  '올리다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a89d30>,
#  '10/Number': <gensim.models.keyedvectors.Vocab at 0x24e48a89d68>,
#  '^^/Punctuation': <gensim.models.keyedvectors.Vocab at 0x24e48a89da0>,
#  '말다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a89dd8>,
#  '낭비/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a89e10>,
#  '돈/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a89e48>,
#  '뛰어나다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a89e80>,
#  '공감/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a89eb8>,
#  '간다/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a89ef0>,
#  '캐릭터/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a89f28>,
#  '상/Suffix': <gensim.models.keyedvectors.Vocab at 0x24e48a89f60>,
#  '극/NounPrefix': <gensim.models.keyedvectors.Vocab at 0x24e48a89f98>,
#  '초반/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a89fd0>,
#  '엔/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a8c048>,
#  '신선하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a8c080>,
#  '가면/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a8c0b8>,
#  '상태/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a8c0f0>,
#  '불가/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a8c128>,
#  '마이너스/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a8c160>,
#  'ㅋ/KoreanParticle': <gensim.models.keyedvectors.Vocab at 0x24e48a8c198>,
#  '수준/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a8c1d0>,
#  '딱/Adverb': <gensim.models.keyedvectors.Vocab at 0x24e48a8c208>,
#  '알/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a8c240>,
#  'ㅉㅉ/KoreanParticle': <gensim.models.keyedvectors.Vocab at 0x24e48a8c278>,
#  '북한/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a8c2b0>,
#  '이렇다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a8c2e8>,
#  '만들다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a8c320>,
#  '대다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a8c358>,
#  '난/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a8c390>,
#  '우리/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a8c3c8>,
#  '사랑/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a8c400>,
#  '이랑/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a8c438>,
#  '이나/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a8c470>,
#  '다니다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a8c4a8>,
#  '소설/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a8c4e0>,
#  '속/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a8c518>,
#  '에선/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a8c550>,
#  '제일/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a8c588>,
#  '자/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a8c5c0>,
#  '라/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a8c5f8>,
#  '터/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a8c630>,
#  '(/Punctuation': <gensim.models.keyedvectors.Vocab at 0x24e48a8c668>,
#  '용/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a8c6a0>,
#  ')/Punctuation': <gensim.models.keyedvectors.Vocab at 0x24e48a8c6d8>,
#  '웃음/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a8c710>,
#  '감독/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a8c748>,
#  '-/Punctuation': <gensim.models.keyedvectors.Vocab at 0x24e48a8c780>,
#  '월드/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a8c7b8>,
#  '아/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a8c7f0>,
#  '기본/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a8c828>,
#  '수도/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a8c860>,
#  '잠시/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a8c898>,
#  '잊다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a8c8d0>,
#  '동화/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a8c908>,
#  '행복하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a8c940>,
#  '야/Exclamation': <gensim.models.keyedvectors.Vocab at 0x24e48a8c978>,
#  '작다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a8c9b0>,
#  '맛/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a8ca58>,
#  '가슴/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a8ca90>,
#  '자체/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a8cac8>,
#  '저/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a8cb00>,
#  '무슨/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a8cb38>,
#  '깊다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a8cb70>,
#  'OO/Alpha': <gensim.models.keyedvectors.Vocab at 0x24e48a8cba8>,
#  '혼자/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a8cbe0>,
#  '전/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a8cc18>,
#  '충격/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a8cc50>,
#  '적다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a8cc88>,
#  '기분/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a8ccc0>,
#  '완전하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a8ccf8>,
#  '푹/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a8cd30>,
#  '느낌/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a8cd68>,
#  '무겁다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a8cda0>,
#  '그저/Adverb': <gensim.models.keyedvectors.Vocab at 0x24e48a8cdd8>,
#  '대단하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a8ce10>,
#  '생각/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a8ce48>,
#  '심심하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a8ce80>,
#  '언제/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a8ceb8>,
#  '그대로/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a8cef0>,
#  '맞다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a8cf28>,
#  '카리스마/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a8cf60>,
#  '악역/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a8cf98>,
#  '당황/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a8cfd0>,
#  '중간/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a91048>,
#  '끝나다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a91080>,
#  '녹다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a910b8>,
#  '일상/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a910f0>,
#  '계속/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a91128>,
#  '주인공/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a91160>,
#  '은희/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a91198>,
#  '적/Suffix': <gensim.models.keyedvectors.Vocab at 0x24e48a911d0>,
#  '모습/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a91208>,
#  'ㅜㅜ/KoreanParticle': <gensim.models.keyedvectors.Vocab at 0x24e48a91240>,
#  '맨날/Adverb': <gensim.models.keyedvectors.Vocab at 0x24e48a91278>,
#  '기대/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a912b0>,
#  '전개/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a912e8>,
#  '좀/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a91320>,
#  '빨리/Adverb': <gensim.models.keyedvectors.Vocab at 0x24e48a91358>,
#  '온/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a91390>,
#  '감정/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a913c8>,
#  '예요/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a91400>,
#  '많다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a91438>,
#  '다큐/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a91470>,
#  '우리나라/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a914a8>,
#  '슬프다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a914e0>,
#  '현대/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a91518>,
#  '대해/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a91550>,
#  '깊이/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a91588>,
#  '바로/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a915c0>,
#  '위해/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a915f8>,
#  '노력/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a91630>,
#  '말로/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a91668>,
#  '듣다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a916a0>,
#  '이정/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a916d8>,
#  '일/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a91710>,
#  '이야/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a91748>,
#  '살인/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a91780>,
#  '어디/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a917b8>,
#  '예전/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a917f0>,
#  '작품/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a91828>,
#  '에피소드/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a91860>,
#  '으로/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a91898>,
#  '가다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a918d0>,
#  '시청률/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a91908>,
#  '이제/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a91940>,
#  '회/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a91978>,
#  '120/Number': <gensim.models.keyedvectors.Vocab at 0x24e48a919b0>,
#  '이라니/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a919e8>,
#  '짜다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a91a20>,
#  '연기력/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a91a58>,
#  '몰입도/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a91a90>,
#  '에도/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a91ac8>,
#  '비슷하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a91b00>,
#  '분/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a91b38>,
#  '한테/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a91b70>,
#  '늘다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a91ba8>,
#  '뽑다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a91be0>,
#  '일본/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a91c18>,
#  '??/Punctuation': <gensim.models.keyedvectors.Vocab at 0x24e48a91c50>,
#  '유치/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a91c88>,
#  '만에/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a91cc0>,
#  '근데/Adverb': <gensim.models.keyedvectors.Vocab at 0x24e48a91cf8>,
#  '차/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a91d30>,
#  '넣다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a91d68>,
#  '조작/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a91da0>,
#  '열리다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a91dd8>,
#  '집/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a91e10>,
#  '무/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a91e48>,
#  '나/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a91e80>,
#  '들어가다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a91eb8>,
#  '걸리다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a91ef0>,
#  '억지/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a91f28>,
#  '스럽다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a91f60>,
#  '그래도/Adverb': <gensim.models.keyedvectors.Vocab at 0x24e48a91f98>,
#  '졸작/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a91fd0>,
#  '빨/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a93048>,
#  '라서/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a93080>,
#  '더/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a930b8>,
#  '어설픈/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a930f0>,
#  '어이/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a93128>,
#  '결말/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a93160>,
#  '냐/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a93198>,
#  '매우/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a931d0>,
#  '실망/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a93208>,
#  '...../Punctuation': <gensim.models.keyedvectors.Vocab at 0x24e48a93240>,
#  '한국영/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a93278>,
#  '화/Suffix': <gensim.models.keyedvectors.Vocab at 0x24e48a932b0>,
#  '흥행/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a932e8>,
#  '코드/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a93320>,
#  '갈등/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a93358>,
#  '뻔하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a93390>,
#  '뭐/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a933c8>,
#  '시작/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a93400>,
#  '분만/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a93438>,
#  '단연/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a93470>,
#  '먹다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a934a8>,
#  '에게/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a934e0>,
#  '뭘/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a93518>,
#  '엉망/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a93550>,
#  '진창/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a93588>,
#  '개/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a935c0>,
#  '우뢰매/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a935f8>,
#  ';;;/Punctuation': <gensim.models.keyedvectors.Vocab at 0x24e48a93630>,
#  '진정/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a93668>,
#  '위대하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a936a0>,
#  '별루/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a936d8>,
#  '좋아하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a93710>,
#  '가요/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a93748>,
#  '눈/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a93780>,
#  '성룡/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a937b8>,
#  '최악/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a937f0>,
#  '때리다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a93828>,
#  '귀엽다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a93860>,
#  '인상/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a93898>,
#  '와/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a938d0>,
#  '강추/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a93908>,
#  '에요/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a93940>,
#  '설정/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a93978>,
#  '새롭다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a939b0>,
#  '밉다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a939e8>,
#  '유/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a93a20>,
#  '잘하다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a93a58>,
#  '대박/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a93a90>,
#  '진심/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a93ac8>,
#  '두/Determiner': <gensim.models.keyedvectors.Vocab at 0x24e48a93b00>,
#  '못/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a93b38>,
#  '게/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a93b70>,
#  '보다/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a93ba8>,
#  '만/Suffix': <gensim.models.keyedvectors.Vocab at 0x24e48a93be0>,
#  '인거/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a93c18>,
#  '쓰다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a93c50>,
#  '술/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a93c88>,
#  '어떻다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a93cc0>,
#  '킬링타임/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a93cf8>,
#  '요/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a93d30>,
#  'ㅎㅎ/KoreanParticle': <gensim.models.keyedvectors.Vocab at 0x24e48a93d68>,
#  '빠지다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a93da0>,
#  '쫌/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a93dd8>,
#  '산만/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a93e10>,
#  ';;/Punctuation': <gensim.models.keyedvectors.Vocab at 0x24e48a93e48>,
#  '태어나다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a93e80>,
#  '처음/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a93eb8>,
#  '불륜/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a93ef0>,
#  '로맨스/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a93f28>,
#  ',,/Punctuation': <gensim.models.keyedvectors.Vocab at 0x24e48a93f60>,
#  '왕/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a93f98>,
#  '아주/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a93fd0>,
#  '머/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a97048>,
#  '명작/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a97080>,
#  '서다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a970b8>,
#  '이상하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a970f0>,
#  'D/Alpha': <gensim.models.keyedvectors.Vocab at 0x24e48a97128>,
#  '......../Punctuation': <gensim.models.keyedvectors.Vocab at 0x24e48a97160>,
#  '소재/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a97198>,
#  '흥미/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a971d0>,
#  '끌/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a97208>,
#  '지만/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a97240>,
#  '투/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a97278>,
#  '몰입/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a972b0>,
#  '보지/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a972e8>,
#  '마르다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a97320>,
#  '특유/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a97358>,
#  '쓸다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a97390>,
#  '현실/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a973c8>,
#  '감/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a97400>,
#  '떨어지다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a97438>,
#  '도대체/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a97470>,
#  '까지/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a974a8>,
#  '잡다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a974e0>,
#  '미국/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a97518>,
#  '따뜻하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a97550>,
#  '뭐임/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a97588>,
#  '생애/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a975c0>,
#  '전부/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a975f8>,
#  '보/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a97630>,
#  '지난/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a97668>,
#  '후/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a976a0>,
#  '남다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a976d8>,
#  '대/Suffix': <gensim.models.keyedvectors.Vocab at 0x24e48a97710>,
#  '봐/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a97748>,
#  '순수하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a97780>,
#  '또한/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a977b8>,
#  '공짜/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a977f0>,
#  '허다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a97828>,
#  '문제/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a97860>,
#  '연기자/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a97898>,
#  '전혀/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a978d0>,
#  '배역/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a97908>,
#  '어울리다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a97940>,
#  '그리고/Conjunction': <gensim.models.keyedvectors.Vocab at 0x24e48a97978>,
#  '상대/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a979b0>,
#  '따로/Adverb': <gensim.models.keyedvectors.Vocab at 0x24e48a979e8>,
#  '놓다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a97a20>,
#  '~~/Punctuation': <gensim.models.keyedvectors.Vocab at 0x24e48a97a58>,
#  '보아/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a97a90>,
#  '아들/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a97ac8>,
#  '젤/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a97b00>,
#  '어느/Adverb': <gensim.models.keyedvectors.Vocab at 0x24e48a97b38>,
#  '쪽/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a97b70>,
#  '....../Punctuation': <gensim.models.keyedvectors.Vocab at 0x24e48a97ba8>,
#  '잘/VerbPrefix': <gensim.models.keyedvectors.Vocab at 0x24e48a97be0>,
#  '모자라다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a97c18>,
#  '나라/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a97c50>,
#  '만들어지다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a97c88>,
#  '..?/Punctuation': <gensim.models.keyedvectors.Vocab at 0x24e48a97cc0>,
#  '나/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a97cf8>,
#  '두/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a97d30>,
#  '교훈/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a97d68>,
#  '당시/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a97da0>,
#  '상황/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a97dd8>,
#  '케이블/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a97e10>,
#  '그만/Adverb': <gensim.models.keyedvectors.Vocab at 0x24e48a97e48>,
#  '담기다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a97e80>,
#  '잼/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a97eb8>,
#  '건지다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a97ef0>,
#  '질/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a97f28>,
#  '린다/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a97f60>,
#  '많이/Adverb': <gensim.models.keyedvectors.Vocab at 0x24e48a97f98>,
#  '떠들다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a97fd0>,
#  '해서/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a9a048>,
#  '성/Suffix': <gensim.models.keyedvectors.Vocab at 0x24e48a9a080>,
#  '20/Number': <gensim.models.keyedvectors.Vocab at 0x24e48a9a0b8>,
#  '보기/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9a0f0>,
#  '믿다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a9a128>,
#  '힘들다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a9a160>,
#  '정도/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9a198>,
#  '고본/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9a1d0>,
#  '마지막/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9a208>,
#  '후반/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9a240>,
#  '살짝/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9a278>,
#  '하지만/Conjunction': <gensim.models.keyedvectors.Vocab at 0x24e48a9a2b0>,
#  '떨다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a9a2e8>,
#  '감히/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9a320>,
#  '하나로/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9a358>,
#  '살/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9a390>,
#  '야하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a9a3c8>,
#  '나르다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a9a400>,
#  '고민/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9a438>,
#  '멀다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a9a470>,
#  '나이/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9a4a8>,
#  '여전하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a9a4e0>,
#  '섹시하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a9a518>,
#  '작가/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9a550>,
#  '용이/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9a588>,
#  '혹/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9a5c0>,
#  '답/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9a5f8>,
#  '여운/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9a630>,
#  '웬만하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a9a668>,
#  '지/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a9a6a0>,
#  '퀄리티/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9a6d8>,
#  '쩔다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a9a710>,
#  '충분하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a9a748>,
#  '개인/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9a780>,
#  '잔인/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9a7b8>,
#  '화끈/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9a7f0>,
#  '아끼다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a9a828>,
#  '지겹다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a9a860>,
#  '역시/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9a898>,
#  '의/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9a8d0>,
#  '일품/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9a908>,
#  '죽이다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a9a940>,
#  '괜찮다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a9a978>,
#  '뜨다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a9a9b0>,
#  '???/Punctuation': <gensim.models.keyedvectors.Vocab at 0x24e48a9a9e8>,
#  '알다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a9aa20>,
#  '자신/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9aa58>,
#  '어린이/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9aa90>,
#  '인/Suffix': <gensim.models.keyedvectors.Vocab at 0x24e48a9aac8>,
#  '조합/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9ab00>,
#  '이란/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a9ab38>,
#  '한국/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9ab70>,
#  '한편/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9aba8>,
#  '외국/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9abe0>,
#  '상상/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9ac18>,
#  '유명하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a9ac50>,
#  '오랜만/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9ac88>,
#  '되어다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a9acc0>,
#  '오늘/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9acf8>,
#  '방송/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9ad30>,
#  '대본/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9ad68>,
#  '완성/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9ada0>,
#  '요즘/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9add8>,
#  '막장/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9ae10>,
#  '해/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9ae48>,
#  '그리다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a9ae80>,
#  '심하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a9aeb8>,
#  '화이팅/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9aef0>,
#  '조절/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9af28>,
#  '김/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9af60>,
#  '역할/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9af98>,
#  '로써/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9afd0>,
#  '까지/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a9f048>,
#  '해내다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a9f080>,
#  '사극/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9f0b8>,
#  '그녀/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9f0f0>,
#  '왠지/Adverb': <gensim.models.keyedvectors.Vocab at 0x24e48a9f128>,
#  '코미디/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9f160>,
#  '장면/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9f198>,
#  '"/Punctuation': <gensim.models.keyedvectors.Vocab at 0x24e48a9f1d0>,
#  '끝/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9f208>,
#  '쯤/Suffix': <gensim.models.keyedvectors.Vocab at 0x24e48a9f240>,
#  '한마디/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9f278>,
#  '""/Punctuation': <gensim.models.keyedvectors.Vocab at 0x24e48a9f2b0>,
#  'ㅈ/KoreanParticle': <gensim.models.keyedvectors.Vocab at 0x24e48a9f2e8>,
#  '!!!/Punctuation': <gensim.models.keyedvectors.Vocab at 0x24e48a9f320>,
#  '성/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9f358>,
#  '죽/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9f390>,
#  '치고/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a9f3c8>,
#  '지키다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a9f400>,
#  '이유/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9f438>,
#  '주/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9f470>,
#  '니/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a9f4a8>,
#  '통/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9f4e0>,
#  '게임/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9f518>,
#  '흥미롭다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a9f550>,
#  'CG/Alpha': <gensim.models.keyedvectors.Vocab at 0x24e48a9f588>,
#  '배경/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9f5c0>,
#  '거슬리다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a9f5f8>,
#  '춤/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9f630>,
#  '어제/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9f668>,
#  '에서/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9f6a0>,
#  '참다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a9f6d8>,
#  '예산/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9f710>,
#  '//Punctuation': <gensim.models.keyedvectors.Vocab at 0x24e48a9f748>,
#  '어리다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a9f780>,
#  '알바/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9f7b8>,
#  '4/Number': <gensim.models.keyedvectors.Vocab at 0x24e48a9f7f0>,
#  '라니/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a9f828>,
#  '아름답다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a9f860>,
#  '읽다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a9f898>,
#  '당하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a9f8d0>,
#  '굉장하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a9f908>,
#  '생기다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48a9f940>,
#  '남자/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9f978>,
#  '애/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9f9b0>,
#  '시종일관/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9f9e8>,
#  '싫다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a9fa20>,
#  '날/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9fa58>,
#  '상당하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48a9fa90>,
#  '네/Suffix': <gensim.models.keyedvectors.Vocab at 0x24e48a9fac8>,
#  '!!!!/Punctuation': <gensim.models.keyedvectors.Vocab at 0x24e48a9fb00>,
#  '주기도/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9fb38>,
#  '얼마나/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9fb70>,
#  '밖에/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48a9fba8>,
#  '화가/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9fbe0>,
#  '티비/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9fc18>,
#  '판/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48a9fc50>,
# ...
#  '~!!/Punctuation': <gensim.models.keyedvectors.Vocab at 0x24e48aa2400>,
#  '♥♥/Foreign': <gensim.models.keyedvectors.Vocab at 0x24e48aa2438>,
#  '청춘/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa2470>,
#  '만이/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48aa24a8>,
#  '넘치다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48aa24e0>,
#  '순간/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa2518>,
#  '돌아오다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48aa2550>,
#  '무한/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa2588>,
#  'TV/Alpha': <gensim.models.keyedvectors.Vocab at 0x24e48aa25c0>,
#  '시리즈/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa25f8>,
#  '중/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa2630>,
#  '이고/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48aa2668>,
#  '결정/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa26a0>,
#  '그/Determiner': <gensim.models.keyedvectors.Vocab at 0x24e48aa26d8>,
#  '표현/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa2710>,
#  '등/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa2748>,
#  '으/Adverb': <gensim.models.keyedvectors.Vocab at 0x24e48aa2780>,
#  '로/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa27b8>,
#  '이든/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48aa27f0>,
#  '히/Adverb': <gensim.models.keyedvectors.Vocab at 0x24e48aa2828>,
#  '면서/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa2860>,
#  '시/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa2898>,
#  '랑/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48aa28d0>,
#  '새벽/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa2908>,
#  '원/Suffix': <gensim.models.keyedvectors.Vocab at 0x24e48aa2940>,
#  '래/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48aa2978>,
#  '~!/Punctuation': <gensim.models.keyedvectors.Vocab at 0x24e48aa29b0>,
#  '신/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa29e8>,
#  '예쁘다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48aa2a20>,
#  '필요/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa2a58>,
#  '다른/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa2a90>,
#  '함/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa2ac8>,
#  '사/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa2b00>,
#  '훈훈하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48aa2b38>,
#  '하라/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa2b70>,
#  '웃기/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa2ba8>,
#  '구성/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa2be0>,
#  '네이버/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa2c18>,
#  '제로/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa2c50>,
#  '설레다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48aa2c88>,
#  '그때/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa2cc0>,
#  '느끼다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48aa2cf8>,
#  '대사/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa2d30>,
#  '높다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48aa2d68>,
#  '더럽다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48aa2da0>,
#  '와/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa2dd8>,
#  '닿다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48aa2e10>,
#  '허무/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa2e48>,
#  '완벽하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48aa2e80>,
#  '조연/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa2eb8>,
#  '꿈/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa2ef0>,
#  '프로/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa2f28>,
#  '훌륭하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48aa2f60>,
#  '급/Suffix': <gensim.models.keyedvectors.Vocab at 0x24e48aa2f98>,
#  'the/Alpha': <gensim.models.keyedvectors.Vocab at 0x24e48aa2fd0>,
#  '마음/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa5048>,
#  '비/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa5080>,
#  '코믹/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa50b8>,
#  '짜임새/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa50f0>,
#  '에는/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48aa5128>,
#  '음/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa5160>,
#  '시대/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa5198>,
#  '일단/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa51d0>,
#  '괴물/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa5208>,
#  '귀신/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa5240>,
#  '댓글/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa5278>,
#  '기/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa52b0>,
#  '가보다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48aa52e8>,
#  '란/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa5320>,
#  '따라가다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48aa5358>,
#  '역/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa5390>,
#  '기도/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa53c8>,
#  '시원하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48aa5400>,
#  '답답하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48aa5438>,
#  '낼/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa5470>,
#  '모순/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa54a8>,
#  '어렵다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48aa54e0>,
#  '전쟁/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa5518>,
#  '묘사/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa5550>,
#  '극장판/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa5588>,
#  '두/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa55c0>,
#  '푸다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48aa55f8>,
#  '했지만/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48aa5630>,
#  '세계/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa5668>,
#  '역사/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa56a0>,
#  '가치/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa56d8>,
#  '색다르다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48aa5710>,
#  '엄마/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa5748>,
#  '지다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48aa5780>,
#  '딸/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa57b8>,
#  '시키다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48aa57f0>,
#  '제발/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa5828>,
#  '책/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa5860>,
#  '미치다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48aa5898>,
#  '따위/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa58d0>,
#  '신다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48aa5908>,
#  '뿐/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa5940>,
#  '드럽/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa5978>,
#  '어쩌다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48aa59b0>,
#  '뿐/Suffix': <gensim.models.keyedvectors.Vocab at 0x24e48aa59e8>,
#  '생생/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa5a20>,
#  '굿/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa5a58>,
#  '시절/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa5a90>,
#  '부터/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa5ac8>,
#  '액션영화/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa5b00>,
#  '범죄/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa5b38>,
#  '느와르/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa5b70>,
#  '영화로/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa5ba8>,
#  '서도/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa5be0>,
#  '작/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa5c18>,
#  '......./Punctuation': <gensim.models.keyedvectors.Vocab at 0x24e48aa5c50>,
#  '뭔가/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa5c88>,
#  '부/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa5cc0>,
#  '본인/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa5cf8>,
#  '피해자/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa5d30>,
#  '묻다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48aa5d68>,
#  'OOO/Alpha': <gensim.models.keyedvectors.Vocab at 0x24e48aa5da0>,
#  '필름/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa5dd8>,
#  '값/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa5e10>,
#  '어디서/Adverb': <gensim.models.keyedvectors.Vocab at 0x24e48aa5e48>,
#  '드/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa5e80>,
#  '안습/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa5eb8>,
#  '짧다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48aa5ef0>,
#  '소리/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa5f28>,
#  '분/Suffix': <gensim.models.keyedvectors.Vocab at 0x24e48aa5f60>,
#  '적당하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48aa5f98>,
#  '만/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aa5fd0>,
#  '스릴러/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aaa048>,
#  '스릴/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aaa080>,
#  '이구/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aaa0b8>,
#  '비추다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48aaa0f0>,
#  'ㅜ/KoreanParticle': <gensim.models.keyedvectors.Vocab at 0x24e48aaa128>,
#  '전달/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aaa160>,
#  '오글거리다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48aaa198>,
#  '월/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aaa1d0>,
#  '편이/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aaa208>,
#  '모든/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aaa240>,
#  '부족하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48aaa278>,
#  '50/Number': <gensim.models.keyedvectors.Vocab at 0x24e48aaa2b0>,
#  '12/Number': <gensim.models.keyedvectors.Vocab at 0x24e48aaa2e8>,
#  '기억/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aaa320>,
#  '이름/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aaa358>,
#  '노래/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aaa390>,
#  '부르다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48aaa3c8>,
#  '즐겁다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48aaa400>,
#  '연인/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aaa438>,
#  '망/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aaa470>,
#  '아이/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aaa4a8>,
#  '시선/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aaa4e0>,
#  '내내/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aaa518>,
#  '굳이/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aaa550>,
#  '겁나다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48aaa588>,
#  '어색/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aaa5c0>,
#  '해보다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48aaa5f8>,
#  '여주/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aaa630>,
#  '인공/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aaa668>,
#  '몰다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48aaa6a0>,
#  '80/Number': <gensim.models.keyedvectors.Vocab at 0x24e48aaa6d8>,
#  '비다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48aaa710>,
#  '다르다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48aaa748>,
#  '여자/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aaa780>,
#  '네/Determiner': <gensim.models.keyedvectors.Vocab at 0x24e48aaa7b8>,
#  '울/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aaa7f0>,
#  '개연/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aaa828>,
#  '굳다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48aaa860>,
#  '장/Suffix': <gensim.models.keyedvectors.Vocab at 0x24e48aaa898>,
#  '당신/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aaa8d0>,
#  '휴/Exclamation': <gensim.models.keyedvectors.Vocab at 0x24e48aaa908>,
#  '호구/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aaa940>,
#  '세기/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aaa978>,
#  '쓸데없이/Adverb': <gensim.models.keyedvectors.Vocab at 0x24e48aaa9b0>,
#  '중요하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48aaa9e8>,
#  '여배우/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aaaa20>,
#  '잇다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48aaaa58>,
#  '거기/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aaaa90>,
#  'ost/Alpha': <gensim.models.keyedvectors.Vocab at 0x24e48aaaac8>,
#  '제목/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aaab00>,
#  '지금/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aaab38>,
#  '앞/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aaab70>,
#  '누군가/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aaaba8>,
#  '얘기/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aaabe0>,
#  '100/Number': <gensim.models.keyedvectors.Vocab at 0x24e48aaac18>,
#  '지루함/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aaac50>,
#  '슬픔/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aaac88>,
#  '아역/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aaacc0>,
#  '파다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48aaacf8>,
#  '싸다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48aaad30>,
#  '딱하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48aaad68>,
#  '비디오/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aaada0>,
#  '돌리다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48aaadd8>,
#  '토록/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48aaae10>,
#  '유쾌/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aaae48>,
#  '닮다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48aaae80>,
#  '이/Suffix': <gensim.models.keyedvectors.Vocab at 0x24e48aaaeb8>,
#  '98/Number': <gensim.models.keyedvectors.Vocab at 0x24e48aaaef0>,
#  '내다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48aaaf28>,
#  '한심하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48aaaf60>,
#  '연예인/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aaaf98>,
#  '장/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aaafd0>,
#  '그러나/Conjunction': <gensim.models.keyedvectors.Vocab at 0x24e48aac048>,
#  '준/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aac080>,
#  '든/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48aac0b8>,
#  '걸다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48aac0f0>,
#  '+/Punctuation': <gensim.models.keyedvectors.Vocab at 0x24e48aac128>,
#  '시나리오/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aac160>,
#  '끼다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48aac198>,
#  '안타깝다/Adjective': <gensim.models.keyedvectors.Vocab at 0x24e48aac1d0>,
#  '돌아가다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48aac208>,
#  '천재/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aac240>,
#  '암/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aac278>,
#  '갈다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48aac2b0>,
#  '대작/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aac2e8>,
#  '과/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aac320>,
#  '5/Number': <gensim.models.keyedvectors.Vocab at 0x24e48aac358>,
#  '개다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48aac390>,
#  '땐/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aac3c8>,
#  '조폭/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aac400>,
#  '지는/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48aac438>,
#  '세상/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aac470>,
#  '살아가다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48aac4a8>,
#  '친구/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aac4e0>,
#  '영상/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aac518>,
#  '처/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aac550>,
#  '기다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48aac588>,
#  '감다/Verb': <gensim.models.keyedvectors.Vocab at 0x24e48aac5c0>,
#  '이상/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aac5f8>,
#  '부분/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aac630>,
#  '둘/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aac668>,
#  '민망/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aac6a0>,
#  '진행/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aac6d8>,
#  '탑/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aac710>,
#  '고/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aac748>,
#  '아빠/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aac780>,
#  '0/Number': <gensim.models.keyedvectors.Vocab at 0x24e48aac7b8>,
#  '빠순이/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aac7f0>,
#  '애니메이션/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aac828>,
#  '의도/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aac860>,
#  '불쾌/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aac898>,
#  '법/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aac8d0>,
#  '년전/Noun': <gensim.models.keyedvectors.Vocab at 0x24e48aac908>,
#  '꺼/Suffix': <gensim.models.keyedvectors.Vocab at 0x24e48aac940>,
#  '보다도/Josa': <gensim.models.keyedvectors.Vocab at 0x24e48aac978>,
#  ...}

# %% [markdown]
# ---
# >이후론 노래가사 분류와 거의 동일합니다

# %%
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf
import matplotlib.pyplot as plt
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# 20단어 이상만 골라내기
data = [(sentences[idx][:20], el[2]) for idx,el in enumerate(naver_tot) if len(sentences[idx])>=20]
data_x = [i[0] for i in data]
data_y = [int(i[1]) for i in data]

# split test set 20%
X_train, X_test, Y_train, Y_test = train_test_split(data_x, data_y, test_size=0.2, random_state=3)

# split validation set 2%
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.02, random_state=3)

# %%
# print('나/Noun => \n ----vector---- \n', model.wv.get_vector('나/Noun'))
print(X_train[100], '=>\n------vector-------\n')
tmp =[model.wv.get_vector(i) for i in X_train[100]]
print(len(tmp), len(tmp[0]))
# Out:
# ['몇몇/Noun', '에피소드/Noun', '는/Josa', '1/Number', '번/Noun', '보아/Noun', '도/Josa', '만족/Noun', ',/Punctuation', '몇몇/Noun', '에피소드/Noun', '는/Josa', '2/Number', '~/Punctuation', '3/Number', '번/Noun', '보아/Noun', '야/Josa', '만족/Noun', ',/Punctuation'] =>
# ------vector-------
#
# 20 100

# %%
sess = tf.InteractiveSession()
Y_train = sess.run(tf.one_hot(Y_train, 2))
Y_val = sess.run(tf.one_hot(Y_val, 2))
Y_test = sess.run(tf.one_hot(Y_test, 2))
print([len(X_train),len(X_train[0])], [len(Y_train),len(Y_train[0])], [len(X_val),len(X_val[0])], [len(Y_val),len(Y_val[0])], len(Y_test))
# Out:
# [839, 20] [839, 2] [18, 20] [18, 2] 215

# %%
tf.reset_default_graph()
# train Parameters
seq_length = 20
data_dim = 100
hidden_dim = 100
output_dim = 2
learning_rate = 0.001
epoch = 5
batch_size = 100

# input place holders
X = tf.placeholder(tf.float32, [None, seq_length*data_dim])
X_re = tf.reshape(X, [-1, seq_length, data_dim])
Y = tf.placeholder(tf.float32, [None, output_dim])

# 2-layer LSTM 
cell = tf.contrib.rnn.MultiRNNCell([tf.contrib.rnn.BasicLSTMCell(num_units=hidden_dim, state_is_tuple=True)
                                    for _ in range(2)], state_is_tuple=True) # multiple layers
outputs, _states = tf.nn.dynamic_rnn(cell, X_re, dtype=tf.float32) # batch major (batch, seq, input)
# (batch, seq, data) -> (seq, batch, data)
# outputs[:, -1] 이렇게 하면 앞의 transpose안해줘도 됨
fc1 = tf.contrib.layers.fully_connected(outputs[:, -1], 100, activation_fn=tf.nn.relu)  # We use the last cell's output

Y_pred = tf.contrib.layers.fully_connected(fc1, output_dim, activation_fn=None)  # We use the last cell's output
hypothesis = tf.nn.softmax(Y_pred)

# cost/loss
cost = tf.reduce_mean(-tf.reduce_sum(Y*tf.log(hypothesis), axis=1))

# optimizer
optimizer = tf.train.AdamOptimizer(learning_rate)
train_step = optimizer.minimize(cost)

# prediction
predicted = tf.argmax(hypothesis, 1)
accuracy = tf.reduce_mean(tf.cast(tf.equal(predicted, tf.argmax(Y, 1)), dtype=tf.float32))

total_iter = epoch*int(len(X_train)/batch_size) # 총 학습횟수
print('total iteration:', total_iter, '...')
# Out:
# total iteration: 40 ...

# %%
# 각 단어들에 word embedding
def tok_embedding(tok_vec):
    w2v_vec = []
    mean = np.mean(model.wv.syn0, axis=0) # github code에 없음... 넣어줘야함
    for i in tok_vec: # 그냥 vec넣으면 134170 다들어감 메모리 절대 부족!!! 파이프라인 구축 필요
        temp =[]
        for j in i:
            try:
                temp += list(model.wv.get_vector(j))
            except:
                temp += list(mean)
        w2v_vec.append(temp)
#     reshape은 텐서플로에서 함
#     w2v_vec = np.array(w2v_vec, dtype='float16')
#     return w2v_vec.reshape([-1,200,embed_dim])
    return w2v_vec

# 피처 데이터, 레이블, 미니배치 갯수, random sampling
import random
def getMiniBatch2(x, y, n):
    if len(x) != len(y):
        print('Feature and label num is not equal.')
        return
    rand_idx = random.sample(list(range(len(x))), n)
    x_ = [x[i] for i in rand_idx]
    y_ = [y[i] for i in rand_idx]
    return tok_embedding(x_), y_

# %%
# %%time
#----------------------
sess = tf.InteractiveSession(config=tf.ConfigProto(log_device_placement=True))
sess.run(tf.global_variables_initializer())

x_range=[]
train_accuracies=[]
val_accuracies=[]
val_costs=[]
X_val_tok = tok_embedding(X_val)

for i in range(total_iter*100):
    X_, Y_ = getMiniBatch2(X_train, Y_train, batch_size) # 랜덤 미니배치 할당
    train_step.run(feed_dict={X:X_, Y:Y_})

#   아래에 결과 프린트용
    if i % 10 == 0:   
        train_accuracy = accuracy.eval(feed_dict={X:X_, Y:Y_})
        val_accuracy, val_cost = sess.run([accuracy, cost], feed_dict={X:X_val_tok, Y:Y_val})
        
        train_accuracies.append(train_accuracy)
        val_accuracies.append(val_accuracy)
        val_costs.append(val_cost)
        x_range.append(i)
        print('step %d: acc_tr %g, acc_tt %g, val_cost %g' % (i, train_accuracy, val_accuracy, val_cost))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.wv.vectors instead).
#   after removing the cwd from sys.path.
# step 0: acc_tr 0.57, acc_tt 0.388889, val_cost 0.700956
# step 10: acc_tr 0.66, acc_tt 0.777778, val_cost 0.528238
# step 20: acc_tr 0.75, acc_tt 0.722222, val_cost 0.590423
# step 30: acc_tr 0.83, acc_tt 0.666667, val_cost 0.565084
# step 40: acc_tr 0.82, acc_tt 0.722222, val_cost 0.641014
# step 50: acc_tr 0.85, acc_tt 0.666667, val_cost 0.562359
# step 60: acc_tr 0.81, acc_tt 0.777778, val_cost 0.656548
# step 70: acc_tr 0.87, acc_tt 0.722222, val_cost 0.676414
# step 80: acc_tr 0.89, acc_tt 0.777778, val_cost 0.654036
# step 90: acc_tr 0.94, acc_tt 0.722222, val_cost 0.866169
# step 100: acc_tr 0.93, acc_tt 0.777778, val_cost 0.702089
# step 110: acc_tr 0.95, acc_tt 0.666667, val_cost 1.02102
# step 120: acc_tr 1, acc_tt 0.666667, val_cost 1.35482
# step 130: acc_tr 1, acc_tt 0.777778, val_cost 1.036
# step 140: acc_tr 1, acc_tt 0.777778, val_cost 1.25761
# step 150: acc_tr 1, acc_tt 0.666667, val_cost 1.51868
# step 160: acc_tr 1, acc_tt 0.722222, val_cost 1.59231
# step 170: acc_tr 1, acc_tt 0.722222, val_cost 1.73548
# step 180: acc_tr 1, acc_tt 0.777778, val_cost 1.57655
# step 190: acc_tr 1, acc_tt 0.722222, val_cost 1.48015
# step 200: acc_tr 1, acc_tt 0.833333, val_cost 1.25922
# step 210: acc_tr 1, acc_tt 0.777778, val_cost 1.65051
# step 220: acc_tr 1, acc_tt 0.666667, val_cost 1.80752
# step 230: acc_tr 1, acc_tt 0.722222, val_cost 2.00359
# step 240: acc_tr 1, acc_tt 0.666667, val_cost 1.4952
# step 250: acc_tr 1, acc_tt 0.666667, val_cost 2.43672
# step 260: acc_tr 1, acc_tt 0.666667, val_cost 2.0889
# step 270: acc_tr 1, acc_tt 0.611111, val_cost 2.2695
# step 280: acc_tr 1, acc_tt 0.777778, val_cost 2.3045
# step 290: acc_tr 1, acc_tt 0.722222, val_cost 2.30015
# step 300: acc_tr 1, acc_tt 0.722222, val_cost 2.31674
# step 310: acc_tr 1, acc_tt 0.722222, val_cost 2.39337
# step 320: acc_tr 1, acc_tt 0.722222, val_cost 2.47294
# step 330: acc_tr 1, acc_tt 0.722222, val_cost 2.51413
# step 340: acc_tr 1, acc_tt 0.722222, val_cost 2.53391
# step 350: acc_tr 1, acc_tt 0.722222, val_cost 2.54505
# step 360: acc_tr 1, acc_tt 0.722222, val_cost 2.55841
# step 370: acc_tr 1, acc_tt 0.722222, val_cost 2.57779
# step 380: acc_tr 1, acc_tt 0.722222, val_cost 2.59291
# step 390: acc_tr 1, acc_tt 0.722222, val_cost 2.61324
# step 400: acc_tr 1, acc_tt 0.722222, val_cost 2.63131
# step 410: acc_tr 1, acc_tt 0.722222, val_cost 2.64319
# step 420: acc_tr 1, acc_tt 0.722222, val_cost 2.65677
# step 430: acc_tr 1, acc_tt 0.777778, val_cost 2.66986
# step 440: acc_tr 1, acc_tt 0.777778, val_cost 2.68282
# step 450: acc_tr 1, acc_tt 0.777778, val_cost 2.69326
# step 460: acc_tr 1, acc_tt 0.777778, val_cost 2.7025
# step 470: acc_tr 1, acc_tt 0.777778, val_cost 2.71168
# step 480: acc_tr 1, acc_tt 0.777778, val_cost 2.7218
# step 490: acc_tr 1, acc_tt 0.777778, val_cost 2.731
# step 500: acc_tr 1, acc_tt 0.777778, val_cost 2.73827
# step 510: acc_tr 1, acc_tt 0.777778, val_cost 2.744
# step 520: acc_tr 1, acc_tt 0.777778, val_cost 2.75136
# step 530: acc_tr 1, acc_tt 0.777778, val_cost 2.76093
# step 540: acc_tr 1, acc_tt 0.777778, val_cost 2.76885
# step 550: acc_tr 1, acc_tt 0.777778, val_cost 2.77457
# step 560: acc_tr 1, acc_tt 0.777778, val_cost 2.78028
# step 570: acc_tr 1, acc_tt 0.777778, val_cost 2.78505
# step 580: acc_tr 1, acc_tt 0.777778, val_cost 2.79132
# step 590: acc_tr 1, acc_tt 0.777778, val_cost 2.79909
# step 600: acc_tr 1, acc_tt 0.777778, val_cost 2.80771
# step 610: acc_tr 1, acc_tt 0.777778, val_cost 2.81635
# step 620: acc_tr 1, acc_tt 0.777778, val_cost 2.82351
# step 630: acc_tr 1, acc_tt 0.777778, val_cost 2.82878
# step 640: acc_tr 1, acc_tt 0.777778, val_cost 2.83204
# step 650: acc_tr 1, acc_tt 0.777778, val_cost 2.836
# step 660: acc_tr 1, acc_tt 0.777778, val_cost 2.84213
# step 670: acc_tr 1, acc_tt 0.777778, val_cost 2.84725
# step 680: acc_tr 1, acc_tt 0.777778, val_cost 2.85316
# step 690: acc_tr 1, acc_tt 0.777778, val_cost 2.8602
# step 700: acc_tr 1, acc_tt 0.777778, val_cost 2.86743
# step 710: acc_tr 1, acc_tt 0.777778, val_cost 2.87294
# step 720: acc_tr 1, acc_tt 0.777778, val_cost 2.87991
# step 730: acc_tr 1, acc_tt 0.777778, val_cost 2.88581
# step 740: acc_tr 1, acc_tt 0.777778, val_cost 2.8919
# step 750: acc_tr 1, acc_tt 0.777778, val_cost 2.8952
# step 760: acc_tr 1, acc_tt 0.777778, val_cost 2.89795
# step 770: acc_tr 1, acc_tt 0.777778, val_cost 2.90262
# step 780: acc_tr 1, acc_tt 0.777778, val_cost 2.90718
# step 790: acc_tr 1, acc_tt 0.777778, val_cost 2.91077
# step 800: acc_tr 1, acc_tt 0.777778, val_cost 2.91472
# step 810: acc_tr 1, acc_tt 0.777778, val_cost 2.91925
# step 820: acc_tr 1, acc_tt 0.777778, val_cost 2.92397
# step 830: acc_tr 1, acc_tt 0.777778, val_cost 2.92973
# step 840: acc_tr 1, acc_tt 0.777778, val_cost 2.93661
# step 850: acc_tr 1, acc_tt 0.777778, val_cost 2.94168
# step 860: acc_tr 1, acc_tt 0.777778, val_cost 2.94642
# step 870: acc_tr 1, acc_tt 0.777778, val_cost 2.95105
# step 880: acc_tr 1, acc_tt 0.777778, val_cost 2.95576
# step 890: acc_tr 1, acc_tt 0.777778, val_cost 2.96056
# step 900: acc_tr 1, acc_tt 0.777778, val_cost 2.96293
# step 910: acc_tr 1, acc_tt 0.777778, val_cost 2.96516
# step 920: acc_tr 1, acc_tt 0.777778, val_cost 2.96884
# step 930: acc_tr 1, acc_tt 0.777778, val_cost 2.97313
# step 940: acc_tr 1, acc_tt 0.777778, val_cost 2.97771
# step 950: acc_tr 1, acc_tt 0.777778, val_cost 2.98318
# step 960: acc_tr 1, acc_tt 0.777778, val_cost 2.98808
# step 970: acc_tr 1, acc_tt 0.777778, val_cost 2.99117
# step 980: acc_tr 1, acc_tt 0.777778, val_cost 2.99397
# step 990: acc_tr 1, acc_tt 0.777778, val_cost 2.99698
# step 1000: acc_tr 1, acc_tt 0.777778, val_cost 3.00003
# step 1010: acc_tr 1, acc_tt 0.777778, val_cost 3.0026
# step 1020: acc_tr 1, acc_tt 0.777778, val_cost 3.00527
# step 1030: acc_tr 1, acc_tt 0.777778, val_cost 3.00783
# step 1040: acc_tr 1, acc_tt 0.777778, val_cost 3.0108
# step 1050: acc_tr 1, acc_tt 0.777778, val_cost 3.01393
# step 1060: acc_tr 1, acc_tt 0.777778, val_cost 3.01857
# step 1070: acc_tr 1, acc_tt 0.777778, val_cost 3.02289
# step 1080: acc_tr 1, acc_tt 0.777778, val_cost 3.0263
# step 1090: acc_tr 1, acc_tt 0.777778, val_cost 3.0295
# step 1100: acc_tr 1, acc_tt 0.777778, val_cost 3.03167
# step 1110: acc_tr 1, acc_tt 0.777778, val_cost 3.03475
# step 1120: acc_tr 1, acc_tt 0.777778, val_cost 3.03933
# step 1130: acc_tr 1, acc_tt 0.777778, val_cost 3.04487
# step 1140: acc_tr 1, acc_tt 0.777778, val_cost 3.04934
# step 1150: acc_tr 1, acc_tt 0.777778, val_cost 3.05328
# step 1160: acc_tr 1, acc_tt 0.777778, val_cost 3.0568
# step 1170: acc_tr 1, acc_tt 0.777778, val_cost 3.05912
# step 1180: acc_tr 1, acc_tt 0.777778, val_cost 3.06164
# step 1190: acc_tr 1, acc_tt 0.777778, val_cost 3.0651
# step 1200: acc_tr 1, acc_tt 0.777778, val_cost 3.06918
# step 1210: acc_tr 1, acc_tt 0.777778, val_cost 3.07277
# step 1220: acc_tr 1, acc_tt 0.777778, val_cost 3.07523
# step 1230: acc_tr 1, acc_tt 0.777778, val_cost 3.0789
# step 1240: acc_tr 1, acc_tt 0.777778, val_cost 3.08143
# step 1250: acc_tr 1, acc_tt 0.777778, val_cost 3.08394
# step 1260: acc_tr 1, acc_tt 0.777778, val_cost 3.08708
# step 1270: acc_tr 1, acc_tt 0.777778, val_cost 3.09073
# step 1280: acc_tr 1, acc_tt 0.777778, val_cost 3.09396
# step 1290: acc_tr 1, acc_tt 0.777778, val_cost 3.09652
# step 1300: acc_tr 1, acc_tt 0.777778, val_cost 3.10064
# step 1310: acc_tr 1, acc_tt 0.777778, val_cost 3.10452
# step 1320: acc_tr 1, acc_tt 0.777778, val_cost 3.10761
# step 1330: acc_tr 1, acc_tt 0.777778, val_cost 3.11032
# step 1340: acc_tr 1, acc_tt 0.777778, val_cost 3.11265
# step 1350: acc_tr 1, acc_tt 0.777778, val_cost 3.11504
# step 1360: acc_tr 1, acc_tt 0.777778, val_cost 3.11884
# step 1370: acc_tr 1, acc_tt 0.777778, val_cost 3.12247
# step 1380: acc_tr 1, acc_tt 0.777778, val_cost 3.12541
# step 1390: acc_tr 1, acc_tt 0.777778, val_cost 3.12846
# step 1400: acc_tr 1, acc_tt 0.777778, val_cost 3.13046
# step 1410: acc_tr 1, acc_tt 0.777778, val_cost 3.13237
# step 1420: acc_tr 1, acc_tt 0.777778, val_cost 3.13544
# step 1430: acc_tr 1, acc_tt 0.777778, val_cost 3.13947
# step 1440: acc_tr 1, acc_tt 0.777778, val_cost 3.14238
# step 1450: acc_tr 1, acc_tt 0.777778, val_cost 3.14476
# step 1460: acc_tr 1, acc_tt 0.777778, val_cost 3.14695
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <timed exec> in <module>()
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in run(self, feed_dict, session)
#    2040         none, the default session will be used.
#    2041     """
# -> 2042     _run_using_default_session(self, feed_dict, self.graph, session)
#    2043
#    2044 _gradient_registry = registry.Registry("gradient")
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in _run_using_default_session(operation, feed_dict, graph, session)
#    4488                        "the operation's graph is different from the session's "
#    4489                        "graph.")
# -> 4490   session.run(operation, feed_dict)
#    4491
#    4492
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1087             feed_handles[subfeed_t] = subfeed_val
#    1088           else:
# -> 1089             np_val = np.asarray(subfeed_val, dtype=subfeed_dtype)
#    1090
#    1091           if (not is_tensor_handle_feed and
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     490
#     491     """
# --> 492     return array(a, dtype, copy=False, order=order)
#     493
#     494
#
# ValueError: setting an array element with a sequence.

# %%
plt.figure(figsize=(18,5))
plt.subplot(121)
plt.plot(x_range, train_accuracies,'-b', label='Training')
plt.plot(x_range, val_accuracies,'-g', label='Validation')
plt.legend(loc='lower right', frameon=False)
# plt.ylim(ymax = 1.1, ymin = 0.7)
plt.ylabel('accuracy')
plt.xlabel('step')
plt.title('RNN: Accuracy')

plt.subplot(122)
plt.plot(x_range, val_costs,'-r', label='Validatin_cost')
plt.legend(loc='lower right', frameon=False)
# plt.ylim(ymax = 1.1, ymin = 0.7)
plt.ylabel('cost')
plt.xlabel('step')
plt.title('RNN: Validation Cost')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c162466218fd> in <module>()
# ----> 1 plt.figure(figsize=(18,5))
#       2 plt.subplot(121)
#       3 plt.plot(x_range, train_accuracies,'-b', label='Training')
#       4 plt.plot(x_range, val_accuracies,'-g', label='Validation')
#       5 plt.legend(loc='lower right', frameon=False)
#
# NameError: name 'plt' is not defined

# %%
# 전체 테스트셋 정확도
acc = accuracy.eval(feed_dict={X: tok_embedding(X_test), Y: Y_test})
print('test accuracy:', acc)

print('0: negative, 1: positive')
pred = predicted.eval(feed_dict={X: tok_embedding([X_test[0]])}) 
print(X_test[0])
print('label:', tf.argmax(Y_test[0]).eval(), 'predicted', pred)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.wv.vectors instead).
#   after removing the cwd from sys.path.
# test accuracy: 0.7209302
# 0: negative, 1: positive
# ['오랜만/Noun', '에/Josa', '보다/Verb', '서부/Noun', '극/Suffix', './Punctuation', '소재/Noun', '도/Josa', '독특하다/Adjective', '음악/Noun', '역시/Noun', '특이하다/Adjective', '가스펠/Noun', '을/Josa', '편곡/Noun', '해서/Josa', '쓰다/Verb', ',/Punctuation', '색다르다/Adjective', './Punctuation']
# label: 1 predicted [1]
